# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0, 1, 100)

# %%
def kit(x):
    return np.exp(x)

# %%
y = kit(x)
plt.plot(x, y)
plt.ylabel('Awesomeness')
plt.xlabel('Time[Milliseconds]')
plt.savefig('Prompt2.1.pdf')
plt.show()
