# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
randy = np.random.binomial(0, 1, 1000)

# %%
plt.hist(randy, bins = 100)

plt.xlabel('Randy Nums')
plt.ylabel('###')

plt.savefig('Prompt2.4.pdf')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
